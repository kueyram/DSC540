# %%
import requests

# Function to get the meal info from the api

def get_meal_info(meal_name):
    # url to get the api
    url = f"https://www.themealdb.com/api/json/v1/1/search.php?s={meal_name}"

    try:
        # Sending a GET request to the API
        response = requests.get(url)
        data = response.json()

        # Let's check if data contains the meal information
        if "meals" in data and data["meals"]:
            # Let's extract information we need from the api
            meal_info = {
                "Meal Name": data["meals"][0]["strMeal"],
                "Category": data["meals"][0]["strCategory"],
                "Area": data["meals"][0]["strArea"],
                "Instructions": data["meals"][0]["strInstructions"],
                "Ingredients": [data["meals"][0][f"strIngredient{i}"] for i in range(1, 21) if data["meals"][0][f"strIngredient{i}"]]
            }
            
            # Printing the meal information
            print("Meal Information:")
            print('******************')
            print(f"Meal Name: {meal_info['Meal Name']}")
            print(f"Category: {meal_info['Category']}")
            print(f"Area: {meal_info['Area']}")
            print(f"Instructions:\n{meal_info['Instructions']}")
            print("Ingredients:")
            for ingredient in meal_info["Ingredients"]:
                print(f"- {ingredient}")
        else:
            # Print a message if no info is available
            print(f"No information available for the meal: {meal_name}")

         # Handling errors 
    except Error as e:
        return f"Error parsing data from the api: {e}"

# %%
# Testing the function
meal_name = "Pasta"
get_meal_info(meal_name)
# Out:
# Meal Information:
# ******************
# Meal Name: Mediterranean Pasta Salad
# Category: Seafood
# Area: Italian
# Instructions:
# Bring a large saucepan of salted water to the boil
# Add the pasta, stir once and cook for about 10 minutes or as directed on the packet.
# Meanwhile, wash the tomatoes and cut into quarters. Slice the olives. Wash the basil.
# Put the tomatoes into a salad bowl and tear the basil leaves over them. Add a tablespoon of olive oil and mix.
# When the pasta is ready, drain into a colander and run cold water over it to cool it quickly.
# Toss the pasta into the salad bowl with the tomatoes and basil.
# Add the sliced olives, drained mozzarella balls, and chunks of tuna. Mix well and let the salad rest for at least half an hour to allow the flavours to mingle.
# Sprinkle the pasta with a generous grind of black pepper and drizzle with the remaining olive oil just before serving.
# Ingredients:
# - mozzarella balls
# - baby plum tomatoes
# - fresh basil
# - farfalle
# - extra virgin olive oil
# - Green Olives
# - tuna
# - salt
# - pepper

# %%
import requests

# URL for the MealDB API to fetch data for a specific meal (e.g., Spaghetti Carbonara)
meal_name = "Spaghetti Carbonara"
url = f"https://www.themealdb.com/api/json/v1/1/search.php?s={meal_name}"

response = requests.get(url)
data = response.json()

# Print a subset of the data
if data["meals"]:
    meal_info = {
        "Meal Name": data["meals"][0]["strMeal"],
        "Category": data["meals"][0]["strCategory"],
        "Area": data["meals"][0]["strArea"],
        "Instructions": data["meals"][0]["strInstructions"],
        "Ingredients": [data["meals"][0][f"strIngredient{i}"] for i in range(1, 21) if data["meals"][0][f"strIngredient{i}"]]
    }
    print(meal_info)
else:
    print(f"No information available for the meal: {meal_name}")
# Out:
#   File <tokenize>:44
#     except requests.exceptions.RequestException as e:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
contents = response.content.decode(response.encoding)
soup = BeautifulSoup(contents, 'html.parser')

# %%
# Empty list to hold all the http links in the HTML page
lst_links=[]
# Find all the href tags and store them in the list of links
for link in soup.find_all('a'):
    #print(link.get('href'))
    lst_links.append(link.get('href'))

    
lst_links[:30]
# Out:
# ['/',
#  '/about/',
#  '/about/',
#  '/policy/collection_development.html',
#  '/about/contact_information.html',
#  '/about/background/',
#  '/policy/permission.html',
#  '/policy/privacy_policy.html',
#  '/policy/terms_of_use.html',
#  '/ebooks/',
#  '/ebooks/',
#  '/ebooks/bookshelf/',
#  '/browse/scores/top',
#  '/ebooks/offline_catalogs.html',
#  '/help/',
#  '/help/',
#  '/help/copyright.html',
#  '/help/errata.html',
#  '/help/file_formats.html',
#  '/help/faq.html',
#  '/policy/',
#  '/help/public_domain_ebook_submission.html',
#  '/help/submitting_your_own_work.html',
#  '/help/mobile.html',
#  '/attic/',
#  '/donate/',
#  '/donate/',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7']

# %%
booknum=[]
for i in range(34,133):
    link=lst_links[i]
    link=link.strip()
    # Regular expression to find the numeric digits in the link (href) string
    n=re.findall('[0-9]+',link)
    if len(n)==1:
        # Append the filenumber casted as integer
        booknum.append(int(n[0]))

# %%
print ("\nThe file numbers for the top 100 ebooks on Gutenberg are shown below\n"+"-"*70)
print(booknum)
# Out:
# The file numbers for the top 100 ebooks on Gutenberg are shown below
# ----------------------------------------------------------------------
# [1513, 1342, 2701, 145, 2641, 100, 37106, 67979, 16389, 6761, 394, 2160, 4085, 6593, 11, 1259, 5197, 64317, 844, 174, 98, 345, 2542, 73637, 5200, 2554, 1400, 43, 28054, 25344, 2000, 1952, 1661, 76, 1727, 73636, 2591, 1260, 20228, 1080, 5740, 46, 6130, 4300, 2600, 219, 1184, 27827, 73631, 768, 996, 1998, 1232, 36, 55, 35899, 74, 30254, 2680, 23, 514, 2814, 120, 45, 244, 2852, 408, 16, 67098, 3207, 3825, 135, 8800, 1250, 16328, 10676, 600, 4363, 25717, 57634, 47629, 73630, 158, 1497, 205, 1399, 730, 8492, 5827, 58585, 73633, 31284, 73638, 10007, 161, 14859, 41445, 33283, 7370]

# %%
import re

# Regular expression to match the text part of each string (excluding the numeric part in parentheses)
name_regex = r"^(.*?)\s*\(\d+\)$"

# Initialize an empty list to store the extracted text
extracted_books = []

# Loop through the list and apply the regex
for book in books_name:
    match = re.match(name_regex, book)
    if match:
        start, end = match.span(1)  # Use span(1) to get the indices of the first capturing group
        extracted_text = book[start:end]
        extracted_books.append(extracted_text)

# Print the list of extracted text
print(extracted_books)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       7 extracted_books = []
#       9 # Loop through the list and apply the regex
# ---> 10 for book in books_name:
#      11     match = re.match(name_regex, book)
#      12     if match:
#
# NameError: name 'books_name' is not defined

# %%
print(soup.text[:2000])
# Out:
# Top 100 | Project Gutenberg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu▾
#
#
#
# About
#           ▾
#
# ▾
#
#
# About Project Gutenberg
# Collection Development
# Contact Us
# History & Philosophy
# Permissions & License
# Privacy Policy
# Terms of Use
#
#
#
# Search and Browse
#       	  ▾
#
# ▾
#
#
# Book Search
# Bookshelves
# Frequently Downloaded
# Offline Catalogs
#
#
#
# Help
#           ▾
#
# ▾
#
#
# All help topics →
# Copyright How-To
# Errata, Fixes and Bug Reports
# File Formats
# Frequently Asked Questions
# Policies →
# Public Domain eBook Submission
# Submitting Your Own Work
# Tablets, Phones and eReaders
# The Attic →
#
#
# Donate
#
#
#
#
#
#
#
#
#
#
# Donation
#
#
#
#
#
#
#
# Frequently Viewed or Downloaded
# These listings are based on the number of times each eBook gets downloaded.
#       Multiple downloads from the same Internet address on the same day count as one download, and addresses that download more than 100 eBooks in a day are considered robots and are not counted.
#
# Downloaded Books
# 2024-05-16376253
# last 7 days3549510
# last 30 days13546936
#
#
#
# Top 100 EBooks yesterday
# Top 100 Authors yesterday
# Top 100 EBooks last 7 days
# Top 100 Authors last 7 days
# Top 100 EBooks last 30 days
# Top 100 Authors last 30 days
#
#
# Top 100 EBooks yesterday
#
# Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (2595)
# Romeo and Juliet by William Shakespeare (2457)
# Pride and Prejudice by Jane Austen (2417)
# Moby Dick; Or, The Whale by Herman Melville (2370)
# Middlemarch by George Eliot (1815)
# A Room with a View by E. M.  Forster (1775)
# The Complete Works of William Shakespeare by William Shakespeare (1709)
# Little Women; Or, Meg, Jo, Beth, and Amy by Louisa May Alcott (1654)
# The Blue Castle: a novel by L. M.  Montgomery (1540)
# The Enchanted April by Elizabeth Von Arnim (1525)
# The Adventures of Ferdinand Count Fathom — Complete by T.  Smollett (1463)
# Cranford by Elizabeth Cleghorn Gaskell (1452)
# The Expedition of Humphry Clinker by T.  Smollett (1417)
# The Adventures of Roderick Random by T.  Smollett (1404)
# History of Tom Jones, a Foundling by Henry Fielding (1384)

# %%
lst_links
# Out:
# ['/',
#  '/about/',
#  '/about/',
#  '/policy/collection_development.html',
#  '/about/contact_information.html',
#  '/about/background/',
#  '/policy/permission.html',
#  '/policy/privacy_policy.html',
#  '/policy/terms_of_use.html',
#  '/ebooks/',
#  '/ebooks/',
#  '/ebooks/bookshelf/',
#  '/browse/scores/top',
#  '/ebooks/offline_catalogs.html',
#  '/help/',
#  '/help/',
#  '/help/copyright.html',
#  '/help/errata.html',
#  '/help/file_formats.html',
#  '/help/faq.html',
#  '/policy/',
#  '/help/public_domain_ebook_submission.html',
#  '/help/submitting_your_own_work.html',
#  '/help/mobile.html',
#  '/attic/',
#  '/donate/',
#  '/donate/',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/ebooks/84',
#  '/ebooks/1513',
#  '/ebooks/1342',
#  '/ebooks/2701',
#  '/ebooks/145',
#  '/ebooks/2641',
#  '/ebooks/100',
#  '/ebooks/37106',
#  '/ebooks/67979',
#  '/ebooks/16389',
#  '/ebooks/6761',
#  '/ebooks/394',
#  '/ebooks/2160',
#  '/ebooks/4085',
#  '/ebooks/6593',
#  '/ebooks/11',
#  '/ebooks/1259',
#  '/ebooks/5197',
#  '/ebooks/64317',
#  '/ebooks/844',
#  '/ebooks/174',
#  '/ebooks/98',
#  '/ebooks/345',
#  '/ebooks/2542',
#  '/ebooks/73637',
#  '/ebooks/5200',
#  '/ebooks/2554',
#  '/ebooks/1400',
#  '/ebooks/43',
#  '/ebooks/28054',
#  '/ebooks/25344',
#  '/ebooks/2000',
#  '/ebooks/1952',
#  '/ebooks/1661',
#  '/ebooks/76',
#  '/ebooks/1727',
#  '/ebooks/73636',
#  '/ebooks/2591',
#  '/ebooks/1260',
#  '/ebooks/20228',
#  '/ebooks/1080',
#  '/ebooks/5740',
#  '/ebooks/46',
#  '/ebooks/6130',
#  '/ebooks/4300',
#  '/ebooks/2600',
#  '/ebooks/219',
#  '/ebooks/1184',
#  '/ebooks/27827',
#  '/ebooks/73631',
#  '/ebooks/768',
#  '/ebooks/996',
#  '/ebooks/1998',
#  '/ebooks/1232',
#  '/ebooks/36',
#  '/ebooks/55',
#  '/ebooks/35899',
#  '/ebooks/74',
#  '/ebooks/30254',
#  '/ebooks/2680',
#  '/ebooks/23',
#  '/ebooks/514',
#  '/ebooks/2814',
#  '/ebooks/120',
#  '/ebooks/45',
#  '/ebooks/244',
#  '/ebooks/2852',
#  '/ebooks/408',
#  '/ebooks/16',
#  '/ebooks/67098',
#  '/ebooks/3207',
#  '/ebooks/3825',
#  '/ebooks/135',
#  '/ebooks/8800',
#  '/ebooks/1250',
#  '/ebooks/16328',
#  '/ebooks/10676',
#  '/ebooks/600',
#  '/ebooks/4363',
#  '/ebooks/25717',
#  '/ebooks/57634',
#  '/ebooks/47629',
#  '/ebooks/73630',
#  '/ebooks/158',
#  '/ebooks/1497',
#  '/ebooks/205',
#  '/ebooks/1399',
#  '/ebooks/730',
#  '/ebooks/8492',
#  '/ebooks/5827',
#  '/ebooks/58585',
#  '/ebooks/73633',
#  '/ebooks/31284',
#  '/ebooks/73638',
#  '/ebooks/10007',
#  '/ebooks/161',
#  '/ebooks/14859',
#  '/ebooks/41445',
#  '/ebooks/33283',
#  '/ebooks/7370',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/browse/authors/s#a65',
#  '/browse/authors/s#a838',
#  '/browse/authors/d#a37',
#  '/browse/authors/a#a68',
#  '/browse/authors/s#a61',
#  '/browse/authors/t#a53',
#  '/browse/authors/w#a111',
#  '/browse/authors/m#a9',
#  '/browse/authors/d#a492',
#  '/browse/authors/d#a314',
#  '/browse/authors/a#a102',
#  '/browse/authors/d#a69',
#  '/browse/authors/m#a36',
#  '/browse/authors/m#a3930',
#  '/browse/authors/g#a2858',
#  '/browse/authors/e#a90',
#  '/browse/authors/r#a2183',
#  '/browse/authors/f#a975',
#  '/browse/authors/c#a7',
#  '/browse/authors/m#a6202',
#  '/browse/authors/i#a861',
#  '/browse/authors/g#a220',
#  '/browse/authors/w#a30',
#  '/browse/authors/s#a35',
#  '/browse/authors/v#a603',
#  '/browse/authors/h#a705',
#  '/browse/authors/n#a779',
#  '/browse/authors/b#a26815',
#  '/browse/authors/f#a537',
#  '/browse/authors/w#a1961',
#  '/browse/authors/t#a136',
#  '/browse/authors/w#a1325',
#  '/browse/authors/f#a420',
#  '/browse/authors/c#a505',
#  '/browse/authors/h#a28',
#  '/browse/authors/p#a93',
#  '/browse/authors/v#a60',
#  '/browse/authors/k#a1735',
#  '/browse/authors/p#a481',
#  '/browse/authors/d#a1896',
#  '/browse/authors/b#a42',
#  '/browse/authors/h#a85',
#  '/browse/authors/j#a94',
#  '/browse/authors/s#a190',
#  '/browse/authors/c#a4161',
#  '/browse/authors/l#a120',
#  '/browse/authors/l#a31136',
#  '/browse/authors/j#a1039',
#  '/browse/authors/k#a132',
#  '/browse/authors/d#a507',
#  '/browse/authors/j#a113',
#  '/browse/authors/c#a125',
#  '/browse/authors/m#a306',
#  '/browse/authors/w#a1736',
#  '/browse/authors/s#a326',
#  '/browse/authors/r#a355',
#  '/browse/authors/c#a80',
#  '/browse/authors/b#a251',
#  '/browse/authors/s#a467',
#  '/browse/authors/g#a586',
#  '/browse/authors/d#a4931',
#  '/browse/authors/l#a79',
#  '/browse/authors/d#a204',
#  '/browse/authors/g#a971',
#  '/browse/authors/g#a972',
#  '/browse/authors/s#a59',
#  '/browse/authors/b#a748',
#  '/browse/authors/c#a451',
#  '/browse/authors/c#a708',
#  '/browse/authors/b#a898',
#  '/browse/authors/l#a9473',
#  '/browse/authors/p#a907',
#  '/browse/authors/f#a26786',
#  '/browse/authors/g#a27',
#  '/browse/authors/h#a23',
#  '/browse/authors/b#a408',
#  '/browse/authors/b#a73',
#  '/browse/authors/b#a48',
#  '/browse/authors/m#a4589',
#  '/browse/authors/t#a942',
#  '/browse/authors/m#a500',
#  '/browse/authors/f#a2703',
#  '/browse/authors/j#a325',
#  '/browse/authors/k#a37155',
#  '/browse/authors/b#a10',
#  '/browse/authors/i#a31265',
#  '/browse/authors/a#a31267',
#  '/browse/authors/a#a902',
#  '/browse/authors/o#a506',
#  '/browse/authors/m#a730',
#  '/browse/authors/m#a17',
#  '/browse/authors/w#a783',
#  '/browse/authors/p#a292',
#  '/browse/authors/b#a1708',
#  '/browse/authors/z#a528',
#  '/browse/authors/m#a1355',
#  '/browse/authors/t#a9854',
#  '/browse/authors/t#a54',
#  '/browse/authors/b#a9248',
#  '/browse/authors/k#a1426',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/ebooks/25717',
#  '/ebooks/84',
#  '/ebooks/1513',
#  '/ebooks/1342',
#  '/ebooks/52106',
#  '/ebooks/2701',
#  '/ebooks/145',
#  '/ebooks/2641',
#  '/ebooks/100',
#  '/ebooks/37106',
#  '/ebooks/67979',
#  '/ebooks/16389',
#  '/ebooks/68419',
#  '/ebooks/6761',
#  '/ebooks/394',
#  '/ebooks/4085',
#  '/ebooks/2160',
#  '/ebooks/6593',
#  '/ebooks/1259',
#  '/ebooks/5197',
#  '/ebooks/11',
#  '/ebooks/13188',
#  '/ebooks/59386',
#  '/ebooks/57493',
#  '/ebooks/64317',
#  '/ebooks/844',
#  '/ebooks/174',
#  '/ebooks/2542',
#  '/ebooks/98',
#  '/ebooks/5200',
#  '/ebooks/73571',
#  '/ebooks/2554',
#  '/ebooks/62878',
#  '/ebooks/345',
#  '/ebooks/41360',
#  '/ebooks/43',
#  '/ebooks/34261',
#  '/ebooks/1400',
#  '/ebooks/46',
#  '/ebooks/24869',
#  '/ebooks/2848',
#  '/ebooks/50657',
#  '/ebooks/76',
#  '/ebooks/49710',
#  '/ebooks/53092',
#  '/ebooks/1952',
#  '/ebooks/39426',
#  '/ebooks/28054',
#  '/ebooks/731',
#  '/ebooks/40533',
#  '/ebooks/61113',
#  '/ebooks/2000',
#  '/ebooks/1080',
#  '/ebooks/50801',
#  '/ebooks/1260',
#  '/ebooks/1727',
#  '/ebooks/15272',
#  '/ebooks/1661',
#  '/ebooks/65392',
#  '/ebooks/2591',
#  '/ebooks/25344',
#  '/ebooks/73584',
#  '/ebooks/27827',
#  '/ebooks/59468',
#  '/ebooks/2600',
#  '/ebooks/71280',
#  '/ebooks/45001',
#  '/ebooks/41625',
#  '/ebooks/4208',
#  '/ebooks/4300',
#  '/ebooks/31628',
#  '/ebooks/20228',
#  '/ebooks/54652',
#  '/ebooks/50747',
#  '/ebooks/6130',
#  '/ebooks/35899',
#  '/ebooks/49266',
#  '/ebooks/3332',
#  '/ebooks/5740',
#  '/ebooks/74',
#  '/ebooks/1232',
#  '/ebooks/44021',
#  '/ebooks/219',
#  '/ebooks/38326',
#  '/ebooks/1998',
#  '/ebooks/47532',
#  '/ebooks/1184',
#  '/ebooks/22815',
#  '/ebooks/30254',
#  '/ebooks/10676',
#  '/ebooks/40437',
#  '/ebooks/40388',
#  '/ebooks/768',
#  '/ebooks/735',
#  '/ebooks/47629',
#  '/ebooks/15293',
#  '/ebooks/16328',
#  '/ebooks/45939',
#  '/ebooks/45',
#  '/ebooks/55',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/browse/authors/s#a65',
#  '/browse/authors/g#a375',
#  '/browse/authors/w#a1961',
#  '/browse/authors/m#a8722',
#  '/browse/authors/s#a838',
#  '/browse/authors/d#a37',
#  '/browse/authors/a#a68',
#  '/browse/authors/w#a46679',
#  '/browse/authors/t#a53',
#  '/browse/authors/s#a61',
#  '/browse/authors/d#a492',
#  '/browse/authors/m#a9',
#  '/browse/authors/w#a111',
#  '/browse/authors/d#a314',
#  '/browse/authors/a#a102',
#  '/browse/authors/m#a36',
#  '/browse/authors/d#a69',
#  '/browse/authors/m#a3930',
#  '/browse/authors/r#a2183',
#  '/browse/authors/e#a90',
#  '/browse/authors/r#a8085',
#  '/browse/authors/g#a2858',
#  '/browse/authors/c#a7',
#  '/browse/authors/f#a975',
#  '/browse/authors/s#a35',
#  '/browse/authors/m#a6202',
#  '/browse/authors/d#a485',
#  '/browse/authors/n#a779',
#  '/browse/authors/g#a220',
#  '/browse/authors/w#a30',
#  '/browse/authors/p#a50041',
#  '/browse/authors/b#a49421',
#  '/browse/authors/v#a603',
#  '/browse/authors/h#a705',
#  '/browse/authors/i#a861',
#  '/browse/authors/t#a136',
#  '/browse/authors/b#a26815',
#  '/browse/authors/b#a45612',
#  '/browse/authors/f#a537',
#  '/browse/authors/s#a326',
#  '/browse/authors/w#a1325',
#  '/browse/authors/v#a60',
#  '/browse/authors/b#a42',
#  '/browse/authors/l#a79',
#  '/browse/authors/w#a955',
#  '/browse/authors/p#a93',
#  '/browse/authors/c#a960',
#  '/browse/authors/m#a37028',
#  '/browse/authors/f#a26786',
#  '/browse/authors/d#a1896',
#  '/browse/authors/c#a505',
#  '/browse/authors/k#a1735',
#  '/browse/authors/f#a4891',
#  '/browse/authors/r#a42532',
#  '/browse/authors/b#a898',
#  '/browse/authors/f#a420',
#  '/browse/authors/j#a94',
#  '/browse/authors/d#a4931',
#  '/browse/authors/h#a85',
#  '/browse/authors/h#a28',
#  '/browse/authors/p#a481',
#  '/browse/authors/k#a132',
#  '/browse/authors/s#a190',
#  '/browse/authors/c#a80',
#  '/browse/authors/j#a1039',
#  '/browse/authors/c#a125',
#  '/browse/authors/j#a113',
#  '/browse/authors/r#a355',
#  '/browse/authors/d#a507',
#  '/browse/authors/s#a59',
#  '/browse/authors/g#a586',
#  '/browse/authors/l#a120',
#  '/browse/authors/w#a1736',
#  '/browse/authors/m#a40857',
#  '/browse/authors/l#a9473',
#  '/browse/authors/r#a2297',
#  '/browse/authors/n#a36133',
#  '/browse/authors/b#a7144',
#  '/browse/authors/b#a2296',
#  '/browse/authors/b#a5446',
#  '/browse/authors/b#a251',
#  '/browse/authors/c#a708',
#  '/browse/authors/o#a39035',
#  '/browse/authors/l#a56676',
#  '/browse/authors/s#a56657',
#  '/browse/authors/v#a7984',
#  '/browse/authors/d#a204',
#  '/browse/authors/c#a451',
#  '/browse/authors/s#a467',
#  '/browse/authors/g#a971',
#  '/browse/authors/g#a972',
#  '/browse/authors/s#a4759',
#  '/browse/authors/u#a8',
#  '/browse/authors/s#a4590',
#  '/browse/authors/d#a40654',
#  '/browse/authors/b#a748',
#  '/browse/authors/b#a43156',
#  '/browse/authors/j#a1050',
#  '/browse/authors/s#a41138',
#  '/browse/authors/p#a907',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/ebooks/84',
#  '/ebooks/1342',
#  '/ebooks/2701',
#  '/ebooks/1513',
#  '/ebooks/145',
#  '/ebooks/2641',
#  '/ebooks/100',
#  '/ebooks/37106',
#  '/ebooks/25717',
#  '/ebooks/16389',
#  '/ebooks/67979',
#  '/ebooks/6761',
#  '/ebooks/394',
#  '/ebooks/11',
#  '/ebooks/4085',
#  '/ebooks/2160',
#  '/ebooks/6593',
#  '/ebooks/1259',
#  '/ebooks/5197',
#  '/ebooks/2542',
#  '/ebooks/844',
#  '/ebooks/64317',
#  '/ebooks/5200',
#  '/ebooks/174',
#  '/ebooks/98',
#  '/ebooks/2554',
#  '/ebooks/345',
#  '/ebooks/43',
#  '/ebooks/1952',
#  '/ebooks/1400',
#  '/ebooks/1080',
#  '/ebooks/20228',
#  '/ebooks/47629',
#  '/ebooks/76',
#  '/ebooks/52106',
#  '/ebooks/1260',
#  '/ebooks/28054',
#  '/ebooks/25344',
#  '/ebooks/46',
#  '/ebooks/2000',
#  '/ebooks/2591',
#  '/ebooks/1661',
#  '/ebooks/219',
#  '/ebooks/10676',
#  '/ebooks/1727',
#  '/ebooks/4300',
#  '/ebooks/5740',
#  '/ebooks/6130',
#  '/ebooks/27827',
#  '/ebooks/2600',
#  '/ebooks/35899',
#  '/ebooks/1232',
#  '/ebooks/408',
#  '/ebooks/1998',
#  '/ebooks/74',
#  '/ebooks/768',
#  '/ebooks/1184',
#  '/ebooks/996',
#  '/ebooks/51793',
#  '/ebooks/30254',
#  '/ebooks/2814',
#  '/ebooks/120',
#  '/ebooks/45',
#  '/ebooks/68419',
#  '/ebooks/33283',
#  '/ebooks/16',
#  '/ebooks/3207',
#  '/ebooks/36',
#  '/ebooks/2852',
#  '/ebooks/55',
#  '/ebooks/514',
#  '/ebooks/2680',
#  '/ebooks/8800',
#  '/ebooks/67098',
#  '/ebooks/24869',
#  '/ebooks/2848',
#  '/ebooks/205',
#  '/ebooks/244',
#  '/ebooks/4363',
#  '/ebooks/600',
#  '/ebooks/58585',
#  '/ebooks/1497',
#  '/ebooks/13188',
#  '/ebooks/57493',
#  '/ebooks/158',
#  '/ebooks/7370',
#  '/ebooks/730',
#  '/ebooks/398',
#  '/ebooks/1250',
#  '/ebooks/50657',
#  '/ebooks/3825',
#  '/ebooks/41445',
#  '/ebooks/59386',
#  '/ebooks/8492',
#  '/ebooks/829',
#  '/ebooks/16328',
#  '/ebooks/23',
#  '/ebooks/35',
#  '/ebooks/105',
#  '/ebooks/26',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/browse/authors/s#a65',
#  '/browse/authors/d#a37',
#  '/browse/authors/s#a838',
#  '/browse/authors/a#a68',
#  '/browse/authors/t#a53',
#  '/browse/authors/s#a61',
#  '/browse/authors/w#a111',
#  '/browse/authors/w#a1961',
#  '/browse/authors/d#a492',
#  '/browse/authors/m#a9',
#  '/browse/authors/d#a314',
#  '/browse/authors/r#a2183',
#  '/browse/authors/d#a69',
#  '/browse/authors/a#a102',
#  '/browse/authors/m#a36',
#  '/browse/authors/g#a2858',
#  '/browse/authors/m#a3930',
#  '/browse/authors/e#a90',
#  '/browse/authors/g#a375',
#  '/browse/authors/c#a7',
#  '/browse/authors/s#a35',
#  '/browse/authors/f#a975',
#  '/browse/authors/m#a8722',
#  '/browse/authors/w#a30',
#  '/browse/authors/n#a779',
#  '/browse/authors/m#a6202',
#  '/browse/authors/i#a861',
#  '/browse/authors/g#a220',
#  '/browse/authors/h#a705',
#  '/browse/authors/v#a603',
#  '/browse/authors/v#a60',
#  '/browse/authors/t#a136',
#  '/browse/authors/k#a1735',
#  '/browse/authors/b#a26815',
#  '/browse/authors/f#a537',
#  '/browse/authors/b#a42',
#  '/browse/authors/w#a1325',
#  '/browse/authors/p#a93',
#  '/browse/authors/s#a326',
#  '/browse/authors/d#a1896',
#  '/browse/authors/h#a28',
#  '/browse/authors/c#a505',
#  '/browse/authors/c#a125',
#  '/browse/authors/f#a420',
#  '/browse/authors/b#a898',
#  '/browse/authors/j#a94',
#  '/browse/authors/d#a4931',
#  '/browse/authors/w#a1736',
#  '/browse/authors/l#a79',
#  '/browse/authors/d#a507',
#  '/browse/authors/j#a113',
#  '/browse/authors/h#a85',
#  '/browse/authors/p#a481',
#  '/browse/authors/j#a1039',
#  '/browse/authors/k#a132',
#  '/browse/authors/c#a80',
#  '/browse/authors/l#a120',
#  '/browse/authors/s#a190',
#  '/browse/authors/b#a251',
#  '/browse/authors/r#a355',
#  '/browse/authors/s#a59',
#  '/browse/authors/g#a586',
#  '/browse/authors/d#a485',
#  '/browse/authors/d#a204',
#  '/browse/authors/r#a8085',
#  '/browse/authors/s#a467',
#  '/browse/authors/g#a971',
#  '/browse/authors/g#a972',
#  '/browse/authors/c#a708',
#  '/browse/authors/l#a9473',
#  '/browse/authors/b#a48',
#  '/browse/authors/w#a46679',
#  '/browse/authors/g#a27',
#  '/browse/authors/f#a26786',
#  '/browse/authors/a#a18',
#  '/browse/authors/c#a451',
#  '/browse/authors/p#a907',
#  '/browse/authors/h#a23',
#  '/browse/authors/b#a748',
#  '/browse/authors/b#a408',
#  '/browse/authors/b#a1708',
#  '/browse/authors/m#a1355',
#  '/browse/authors/u#a8',
#  '/browse/authors/k#a1426',
#  '/browse/authors/w#a104',
#  '/browse/authors/t#a54',
#  '/browse/authors/m#a4589',
#  '/browse/authors/b#a10',
#  '/browse/authors/m#a306',
#  '/browse/authors/l#a7862',
#  '/browse/authors/b#a73',
#  '/browse/authors/m#a500',
#  '/browse/authors/k#a37155',
#  '/browse/authors/m#a730',
#  '/browse/authors/m#a17',
#  '/browse/authors/o#a506',
#  '/browse/authors/l#a761',
#  '/browse/authors/d#a226',
#  '/browse/authors/c#a2229',
#  '/browse/authors/r#a2297',
#  '#books-last1',
#  '#authors-last1',
#  '#books-last7',
#  '#authors-last7',
#  '#books-last30',
#  '#authors-last30',
#  '/policy/privacy_policy.html',
#  '/about/',
#  '/policy/terms_of_use.html',
#  '/about/contact_information.html',
#  '/help/',
#  'https://www.ibiblio.org/']
