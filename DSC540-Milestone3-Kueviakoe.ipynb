# %% [raw]
# DSC 540 - Data Preparation
# Milestone 3

# %%
# Librairies
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# Importing the dataset
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_past_and_projected_future_population'

# Let's send a get request
response = requests.get(url)

# Let's add a control to check if the request was successful
if response.status_code == 200:
    # Read the page
    soup = BeautifulSoup(response.content, 'html.parser')

else:
    print("There was an error:", response.status_code)

# %%
# Finding all tables
tables = soup.find_all('table', {'class': 'wikitable'})

# Number of tables
num_tables = len(tables)
print('The number of tables is ', num_tables)
# Out:
# The number of tables is  4

# %%
# Function to convert the table to dataframe
def table_to_df(table):
    # Extracting column headers
    headers = [header.get_text(strip=True) for header in table.find_all('th')]
    
    # Extracting rows
    rows = []
    for row in table.find_all('tr'):
        columns = row.find_all(['td', 'th'])
        rows.append([column.get_text(strip=True) for column in columns])
    
    # Creatinng the dataframe
    df = pd.DataFrame(rows, columns=headers)  
    
    return df

# %%
# Let's create a list to store the dataframes
dataframes = []

# We are iterating over the tables and converting them to dataframe
for table in tables:
    df = table_to_df(table)
    dataframes.append(df)

# %%
len(dataframes)
# Out:
# 4

# %% [raw]
# The source has 3 tables
# - Table 1: Population from 1950 to 1980
# - Table 2: Population from 1985 to 2015
# - Table 3: Population from 2020 to 2050
# For this projet, we are exploring how social and economic factors are linked to suicide rates across different countries from 1990 to 2022. Therefore, we do not need the Table 1 which has the population from 1950 to 1980

# %%
# Extracting dataframes we need from the list
# Dataset for the population from 1985 to 2015
df_pop_85_15 = dataframes[2]

# Dataset for the population from 2020 to 2050
df_pop_20_50 = dataframes[3]

# %%
# Printing the first 5 rows of the dataframes
df_pop_85_15.head(5)
# Out:
#    Country (or dependent territory)    1985      %    1990     %    1995  \
# 0  Country (or dependent territory)    1985      %    1990     %    1995
# 1                       Afghanistan  13,120  -2.70  13,569  0.67  19,446
# 2                           Albania   2,957   2.05   3,245  1.88   3,159
# 3                           Algeria  22,009   3.19  25,191  2.74  28,322
# 4                    American Samoa      39   3.57      48  4.09      54
#
#        %    2000     %    2005      %    2010      %    2015      %
# 0      %    2000     %    2005      %    2010      %    2015      %
# 1   7.46  22,462  2.93  26,335   3.23  29,121   2.03  32,565   2.26
# 2  -0.54   3,159  0.00   3,025  -0.86   2,987  -0.25   3,030   0.28
# 3   2.37  30,639  1.58  32,918   1.45  35,950   1.78  39,543   1.92
# 4   2.69      58  1.39      57  -0.28      56  -0.53      55  -0.41

# %%
df_pop_20_50.head(5)
# Out:
#    Country (or dependent territory)    2020      %    2025      %    2030  \
# 0  Country (or dependent territory)    2020      %    2025      %    2030
# 1                       Afghanistan  36,644   2.39  41,118   2.33  45,665
# 2                           Albania   3,075   0.30   3,105   0.20   3,103
# 3                           Algeria  42,973   1.68  45,842   1.30  48,149
# 4                    American Samoa      54  -0.21      54  -0.17      53
#
#        %    2035      %    2040      %    2045      %    2050      %
# 0      %    2035      %    2040      %    2045      %    2050      %
# 1   2.12  50,195   1.91  54,717   1.74  59,256   1.61  63,796   1.49
# 2  -0.01   3,063  -0.26   2,994  -0.45   2,913  -0.55   2,825  -0.61
# 3   0.99  50,118   0.80  52,030   0.75  53,894   0.71  55,445   0.57
# 4  -0.32      52  -0.45      51  -0.45      50  -0.29      50  -0.06

# %%
# The header is repeated on the 1st row, we will delete it on both dataframes
df_pop_85_15 = df_pop_85_15.drop(index=0)
df_pop_20_50 = df_pop_20_50.drop(index=0)

# %%
df_pop_85_15.head(5)
# Out:
#   Country (or dependent territory)    1985      %    1990     %    1995  \
# 1                      Afghanistan  13,120  -2.70  13,569  0.67  19,446
# 2                          Albania   2,957   2.05   3,245  1.88   3,159
# 3                          Algeria  22,009   3.19  25,191  2.74  28,322
# 4                   American Samoa      39   3.57      48  4.09      54
# 5                          Andorra      45   5.84      53  3.41      64
#
#        %    2000     %    2005      %    2010      %    2015      %
# 1   7.46  22,462  2.93  26,335   3.23  29,121   2.03  32,565   2.26
# 2  -0.54   3,159  0.00   3,025  -0.86   2,987  -0.25   3,030   0.28
# 3   2.37  30,639  1.58  32,918   1.45  35,950   1.78  39,543   1.92
# 4   2.69      58  1.39      57  -0.28      56  -0.53      55  -0.41
# 5   3.70      66  0.58      77   3.18      85   2.12      86   0.25

# %%
df_pop_20_50.head(5)
# Out:
#   Country (or dependent territory)    2020      %    2025      %    2030  \
# 1                      Afghanistan  36,644   2.39  41,118   2.33  45,665
# 2                          Albania   3,075   0.30   3,105   0.20   3,103
# 3                          Algeria  42,973   1.68  45,842   1.30  48,149
# 4                   American Samoa      54  -0.21      54  -0.17      53
# 5                          Andorra      86   0.01      86  -0.12      85
#
#        %    2035      %    2040      %    2045      %    2050      %
# 1   2.12  50,195   1.91  54,717   1.74  59,256   1.61  63,796   1.49
# 2  -0.01   3,063  -0.26   2,994  -0.45   2,913  -0.55   2,825  -0.61
# 3   0.99  50,118   0.80  52,030   0.75  53,894   0.71  55,445   0.57
# 4  -0.32      52  -0.45      51  -0.45      50  -0.29      50  -0.06
# 5  -0.21      83  -0.30      82  -0.46      79  -0.69      75  -0.93

# %% [raw]
# Transformation 1: Remove row with the label %. For our analysis, we need the population, not the percentage of increase or decrease of the population

# %%
# Let's remove the columns where the labels are %
df_pop_85_15 = df_pop_85_15.drop(['%'], axis=1)
df_pop_20_50 = df_pop_20_50.drop(['%'], axis=1)

# %%
df_pop_20_50.columns
# Out:
# Index(['Country (or dependent territory)', '2020', '2025', '2030', '2035',
#        '2040', '2045', '2050'],
#       dtype='object')

# %% [raw]
# Transformation 2: Remove data from year we do not need for the analysis.
# - For the dataframe df_pop_85_15, let's remove the columns with population in 1985. Our analysus start from 1990

# %%
# Dropping columns
df_pop_85_15 = df_pop_85_15.drop(['1985'], axis = 1)

# %% [raw]
# Transformation 3: Removing data from years 2025 to 2050
# For the dataframe df_pop_20_50, let's remove the columns with population from 2025 t0 2050. Our analysis is from 1990 to 2022

# %%
# Removing the columns we do not need for our analysis
df_pop_20_50 = df_pop_20_50.drop(['2025','2030','2035','2040','2045','2050'], axis=1)
df_pop_20_50.head(5)
# Out:
#   Country (or dependent territory)    2020
# 1                      Afghanistan  36,644
# 2                          Albania   3,075
# 3                          Algeria  42,973
# 4                   American Samoa      54
# 5                          Andorra      86

# %% [raw]
# Transformation 4: Joining the 2 dataframes
# At this step, we are going to join the 2 dataframes together to have 1 dataframe that will be use for our analysis.
# Before joining the 2 dataframes, let's check the size of each dataframe

# %%
# Printing the size of each dataframe
print('The size of df_pop_85_15 is ', df_pop_85_15.shape)
print('The size of df_pop_20_50 is ', df_pop_20_50.shape)
# Out:
# The size of df_pop_85_15 is  (227, 7)
# The size of df_pop_20_50 is  (228, 2)

# %% [raw]
# We can see that df_pop_20_50 has more column than df_pop_20_50. This means what after merging the 2 dataframes, we will have rows with missing values.

# %%
# Let's rename the 1st column and call it Country
df_pop_85_15.rename(columns={'Country (or dependent territory)': 'Country'}, inplace = True)
df_pop_20_50.rename(columns={'Country (or dependent territory)': 'Country'}, inplace = True)

# Let's set the Country column as key
df_pop_85_15.set_index('Country')
df_pop_20_50.set_index('Country')

# Combining the 2 dataframes on Country with a suffix
df_country_population = df_pop_85_15.merge(df_pop_20_50, on='Country', how='outer')

# Printing the new dataframe
df_country_population.head(10)
# Out:
#                Country    1990    1995    2000    2005    2010    2015    2020
# 0          Afghanistan  13,569  19,446  22,462  26,335  29,121  32,565  36,644
# 1              Albania   3,245   3,159   3,159   3,025   2,987   3,030   3,075
# 2              Algeria  25,191  28,322  30,639  32,918  35,950  39,543  42,973
# 3       American Samoa      48      54      58      57      56      55      54
# 4              Andorra      53      64      66      77      85      86      86
# 5               Angola   9,486  11,000  12,683  14,770  17,043  19,626  22,485
# 6             Anguilla       9      10      12      14      15      17      19
# 7  Antigua and Barbuda      65      69      76      82      87      93      99
# 8            Argentina  33,036  35,274  37,336  39,182  41,344  43,432  45,379
# 9              Armenia   3,530   3,131   3,101   3,085   3,072   3,057   3,022

# %%
#Let's check the size of the final dataframe
df_country_population.shape
# Out:
# (228, 8)

# %% [raw]
# Transformation 5: Checking for duplicates

# %%
# Looking for duplicates
duplicate_rows = df_country_population.duplicated()
# Number of duplicated rows
print("Number of duplicated rows")
print (duplicate_rows.sum())
# Out:
# Number of duplicated rows
# 0

# %% [raw]
# There is no duplicated row in the dataset

# %% [raw]
# Transformation 6: Check for missing values
# At this stage, we are checking for any missing values. Missing values can indicate that there are data entry errors or the data is incomplete. Identifying and handling the missing values will ensure that the dataset is accurate and has all the information we need for our analysis.

# %%
# Check for NaN values in each column
nan_columns = df_country_population.columns[df_country_population.isnull().any()]

# Print columns with NaN values, if any
if len(nan_columns) > 0:
    print("Columns with NaN values:")
    print(nan_columns)
else:
    print("No columns with NaN values.")
# Out:
# Columns with NaN values:
# Index(['1990', '1995', '2000', '2005', '2010', '2015'], dtype='object')

# %%
# Print rows with missing values
print(df_country_population[df_country_population.isnull().any(axis=1)])
# Out:
#     Country 1990 1995 2000 2005 2010 2015 2020
# 227   Aruba  NaN  NaN  NaN  NaN  NaN  NaN  120

# %% [raw]
# This shows that there is 1 row with missing values. The Country is Aruba is missing population from years prior to 2020. This is because Aruba was not in the dataframe df_pop_85_15.

# %% [raw]
# Transformation 7: Handling missinfg values
# The dataframe has only 1 row with missing values, we will remove the row

# %%
# Dropping the row with missing values. Only 1 row will be deleted
df_country_population.dropna(axis='index', inplace=True)

# %%
# Checking the size of the dataframe
df_country_population.shape
# Out:
# (227, 8)

# %% [raw]
# Transformation 8: Convert the country name to uppercase

# %%
# Converting country to upper cases
df_country_population['Country'] = df_country_population['Country'].str.upper()

# Printing the first 5 rows
df_country_population.head(5)
# Out:
#           Country    1990    1995    2000    2005    2010    2015    2020
# 0     AFGHANISTAN  13,569  19,446  22,462  26,335  29,121  32,565  36,644
# 1         ALBANIA   3,245   3,159   3,159   3,025   2,987   3,030   3,075
# 2         ALGERIA  25,191  28,322  30,639  32,918  35,950  39,543  42,973
# 3  AMERICAN SAMOA      48      54      58      57      56      55      54
# 4         ANDORRA      53      64      66      77      85      86      86

# %% [raw]
# Transformation 9: Removing the comma ',' from the population values
# There is a comma in the population. We will need to remove the comma ',' otherwise, we won't be able to make any calculation with the value. It will be seen as characters instead of numerals

# %%
# Removing commas from the population
df_country_population[df_country_population.columns[1:]] = df_country_population[df_country_population.columns[1:]].replace(',', '', regex=True)

# Printing the first few rows
df_country_population.head(5)
# Out:
#           Country   1990   1995   2000   2005   2010   2015   2020
# 0     AFGHANISTAN  13569  19446  22462  26335  29121  32565  36644
# 1         ALBANIA   3245   3159   3159   3025   2987   3030   3075
# 2         ALGERIA  25191  28322  30639  32918  35950  39543  42973
# 3  AMERICAN SAMOA     48     54     58     57     56     55     54
# 4         ANDORRA     53     64     66     77     85     86     86

# %% [raw]
# Transformation 10: Convert the population to numeral and compute the real population
# The population provided by the website is in the thousands. Let's calculate the real population

# %%
# Function to convert non numerical values to numerals
def compute_population(df):
    # Select population columns (excluding the country names)
    population_cols = df.columns[1:]
    
    # Converting population to numerals
    df[population_cols] = df[population_cols].apply(pd.to_numeric, errors='coerce')
    
    # Multiply by 1000
    df[population_cols] *= 1000
    
    return df
    
df_country_population = compute_population(df_country_population)
df_country_population.head()
# Out:
#           Country      1990      1995      2000      2005      2010      2015  \
# 0     AFGHANISTAN  13569000  19446000  22462000  26335000  29121000  32565000
# 1         ALBANIA   3245000   3159000   3159000   3025000   2987000   3030000
# 2         ALGERIA  25191000  28322000  30639000  32918000  35950000  39543000
# 3  AMERICAN SAMOA     48000     54000     58000     57000     56000     55000
# 4         ANDORRA     53000     64000     66000     77000     85000     86000
#
#        2020
# 0  36644000
# 1   3075000
# 2  42973000
# 3     54000
# 4     86000

# %% [raw]
# List of transformations:
# After scrapping the website and acquiring the data, here are the transformations we made to the dataframe
# Step 1: Removing rows with the label %.
# Step 2: Dropping columns from years we do not need from our analysis
# Step 3: Remove data from years 2025 to 2050
# Step 4: Joining the 2 dataframes
# Step 5: Checking for duplicates
# Step 6: Checking for missing values
# Step 7: Handling missing values
# Step 8: Converting the country name to uppercase
# Step 9: Removing the comma ',' from the population values
# Step 10: Converting the population to numeral and computer the real population

# %% [raw]
# For this project, we were able to verify the source of the dataset.
# The data is available to the public and was acquired from Wikipedia and the sources of the data are the United Nations (UN), the International Monetary Fund and the United States Census Bureau - International Data Base, which are all reliable sources.
# Because the accuracy of the data will impact the analysis, we are making sure that the transformations maintain the integrity and accuracy of the data. We  also documented all the transformations. We also made sure we were not introducing any errors or biases in the dataset.

# %%
df = df_country_population

# %%
df_melted = pd.melt(df, id_vars=['Country'], var_name='Year', value_name='Population')

# %%
df_melted.to_csv('country_population.csv')
