# %% [raw]
# DSC 540 - Data Preparation
# Milestone 2

# %%
# Librairies
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# Importing the dataset
url = 'https://raw.githubusercontent.com/kueyram/DSC540/main/suicide_rates_1990_2022.csv'
suicide_rates = pd.read_csv(url)

# %%
# Columns
suicide_rates.columns
# Out:
# Index(['CodeRegion', 'Nom_Region', 'Code_Pays', 'Nom_Pays', 'Annee', 'Sex',
#        'Nombre_Suicide', 'RatioDecesPar100K', 'GDPPerCapita', 'GNIPerCapita',
#        'InflationRate', 'EmploymentPopulationRatio'],
#       dtype='object')

# %%
# Size of the dataset
suicide_rates.shape
# Out:
# (5928, 12)

# %%
# Viewing the 1st 5 rows
suicide_rates.head(10)
# Out:
#   CodeRegion Nom_Region Code_Pays Nom_Pays  Annee     Sex  Nombre_Suicide  \
# 0         EU     Europe       ALB  Albania   1992    Male              33
# 1         EU     Europe       ALB  Albania   1992  Female              14
# 2         EU     Europe       ALB  Albania   1993    Male              46
# 3         EU     Europe       ALB  Albania   1993  Female              27
# 4         EU     Europe       ALB  Albania   1994    Male              37
# 5         EU     Europe       ALB  Albania   1994  Female              15
# 6         EU     Europe       ALB  Albania   1995    Male              57
# 7         EU     Europe       ALB  Albania   1995  Female              34
# 8         EU     Europe       ALB  Albania   1996    Male              53
# 9         EU     Europe       ALB  Albania   1996  Female              39
#
#    RatioDecesPar100K  GDPPerCapita  GNIPerCapita  InflationRate  \
# 0           2.076386    200.852220        1740.0     226.005421
# ...

# %% [raw]
# Tranformation 1: Replacing headers
# The dataset has some columns name in french. We will replace the headers to have all the names in english.
# Making this change will ensure consistency and compatibility with the rest of the dataset. It will also make the dataset more accessible to a wider audience.

# %%
new_column_names = {
    'CodeRegion': 'RegionCode',
    'Nom_Region': 'Region',
    'Code_Pays': 'CountryCode',
    'Nom_Pays': 'Country',
    'Annee': 'Year',
    'Sex': 'Gender',
    'Nombre_Suicide': 'SuicideCount',
    'RatioDecesPar100K': 'DeathRatePer100K',
    'GDPPerCapita': 'GDPPerCapita',
    'GNIPerCapita': 'GNIPerCapita',
    'InflationRate': 'InflationRate',
    'EmploymentPopulationRatio': 'EmploymentPopulationRatio'
}

# Rename the columns using the new names
suicide_rates.rename(columns=new_column_names, inplace=True)

# View the new columns
suicide_rates.columns
# Out:
# Index(['RegionCode', 'Region', 'CountryCode', 'Country', 'Year', 'Gender',
#        'SuicideCount', 'DeathRatePer100K', 'GDPPerCapita', 'GNIPerCapita',
#        'InflationRate', 'EmploymentPopulationRatio'],
#       dtype='object')

# %%
# Viewing the 1st 5 rows
suicide_rates.head(10)
# Out:
#   RegionCode  Region CountryCode  Country  Year  Gender  SuicideCount  \
# 0         EU  Europe         ALB  Albania  1992    Male            33
# 1         EU  Europe         ALB  Albania  1992  Female            14
# 2         EU  Europe         ALB  Albania  1993    Male            46
# 3         EU  Europe         ALB  Albania  1993  Female            27
# 4         EU  Europe         ALB  Albania  1994    Male            37
# 5         EU  Europe         ALB  Albania  1994  Female            15
# 6         EU  Europe         ALB  Albania  1995    Male            57
# 7         EU  Europe         ALB  Albania  1995  Female            34
# 8         EU  Europe         ALB  Albania  1996    Male            53
# 9         EU  Europe         ALB  Albania  1996  Female            39
#
#    DeathRatePer100K  GDPPerCapita  GNIPerCapita  InflationRate  \
# 0          2.076386    200.852220        1740.0     226.005421
# 1          0.874563    200.852220        1740.0     226.005421
# ...

# %% [raw]
# Transformation 2: Dropping RegionCode and CountryCode
# The dataset has columns called RegionName and CountryName. The dataset also has columns called Region and Country which has the name of the region and the country name. This means that the information in the dataset is redundant. We will remove the regionCode and CountryCode

# %%
# Columns to drop
columns_to_drop = ['RegionCode', 'CountryCode']

# Dropping the columns
suicide_rates = suicide_rates.drop(columns = columns_to_drop)

# View the existing columns
suicide_rates.columns
# Out:
# Index(['Region', 'Country', 'Year', 'Gender', 'SuicideCount',
#        'DeathRatePer100K', 'GDPPerCapita', 'GNIPerCapita', 'InflationRate',
#        'EmploymentPopulationRatio'],
#       dtype='object')

# %%
# Viewing the 1st 5 rows
suicide_rates.head(10)
# Out:
#    Region  Country  Year  Gender  SuicideCount  DeathRatePer100K  \
# 0  Europe  Albania  1992    Male            33          2.076386
# 1  Europe  Albania  1992  Female            14          0.874563
# 2  Europe  Albania  1993    Male            46          2.937233
# 3  Europe  Albania  1993  Female            27          1.686025
# 4  Europe  Albania  1994    Male            37          2.332619
# 5  Europe  Albania  1994  Female            15          0.928333
# 6  Europe  Albania  1995    Male            57          3.545217
# 7  Europe  Albania  1995  Female            34          2.071781
# 8  Europe  Albania  1996    Male            53          3.263547
# 9  Europe  Albania  1996  Female            39          2.350814
#
#    GDPPerCapita  GNIPerCapita  InflationRate  EmploymentPopulationRatio
# 0    200.852220        1740.0     226.005421                     45.315
# 1    200.852220        1740.0     226.005421                     45.315
# ...

# %% [raw]
# Transformation 3: Remove DeathRatePer100K, GDPPerCapita, GNIPerCapita
# The dataset has some calculated columns but does not specify how they were calculated. Bcause we are uncertain about the calculation methods, we can not guarantee their accuracy and reliability. Also, if we need these columns for our analysis, we can make these calculation using up to date information from the other data sources.

# %%
# Columns to drop
columns_to_drop = ['DeathRatePer100K', 'GDPPerCapita', 'GNIPerCapita']

# Dropping the columns
suicide_rates = suicide_rates.drop(columns = columns_to_drop)

# View the existing columns
suicide_rates.columns
# Out:
# Index(['Region', 'Country', 'Year', 'Gender', 'SuicideCount', 'InflationRate',
#        'EmploymentPopulationRatio'],
#       dtype='object')

# %% [raw]
# Transformation 4: Drop Inflation rate and EmploymentPopulationRatio
# The dataset does not specify the source of the Inflation rate and EmploymentPopulationRatio. We will be obtaining these metrics from the API source. Keeping these columns in these dataset may lead to inaccuracies in the analysis.

# %%
# Columns to drop
columns_to_drop = ['InflationRate', 'EmploymentPopulationRatio']

# Dropping the columns
suicide_rates = suicide_rates.drop(columns = columns_to_drop)

# View the existing columns
suicide_rates.columns
# Out:
# Index(['Region', 'Country', 'Year', 'Gender', 'SuicideCount'], dtype='object')

# %% [raw]
# Transformation 5: Convert Region and Country to upper case
# Converting the Region and Country into upper case format will ensure uniformity and consistensy of the names throughout the datast. It is will make is easier when we need to group the data by country or region. The orginal dataset is not uniform and some names are in lower cases and some in upper cases.

# %%
suicide_rates['Region'] = suicide_rates['Region'].str.upper()
suicide_rates['Country'] = suicide_rates['Country'].str.upper()
# Viewing the 1st 5 rows
suicide_rates.head(10)
# Out:
#    Region  Country  Year  Gender  SuicideCount
# 0  EUROPE  ALBANIA  1992    Male            33
# 1  EUROPE  ALBANIA  1992  Female            14
# 2  EUROPE  ALBANIA  1993    Male            46
# 3  EUROPE  ALBANIA  1993  Female            27
# 4  EUROPE  ALBANIA  1994    Male            37
# 5  EUROPE  ALBANIA  1994  Female            15
# 6  EUROPE  ALBANIA  1995    Male            57
# 7  EUROPE  ALBANIA  1995  Female            34
# 8  EUROPE  ALBANIA  1996    Male            53
# 9  EUROPE  ALBANIA  1996  Female            39

# %% [raw]
# Transformation 6: Looking for duplicates
# Identifying and handling duplicates will hep to maintain data accuracy and integrity. Duplicated entries can lead to incorrect conclusions if not addressed.

# %%
# Looking for duplicates
duplicate_rows = suicide_rates[suicide_rates.duplicated()]
# Number of duplicated rows
print("Number of duplicated rows")
print(len(duplicate_rows))
# Out:
# Number of duplicated rows
# 0

# %% [raw]
# The result shows that the dataset does not have any duplicated row.

# %% [raw]
# Transformation 7: Identify missing values
# At this stage, we are checking for any missing values. Missing values can indicate that there are data entry errors or the data is incomplete. Identifying and handling the missing values will ensure that the dataset is accurate and has all the information we need for our analysis.

# %%
# Check for NaN values in each column
nan_columns = suicide_rates.columns[suicide_rates.isnull().any()]

# Print columns with NaN values, if any
if len(nan_columns) > 0:
    print("Columns with NaN values:")
    print(nan_columns)
else:
    print("No columns with NaN values.")
# Out:
# No columns with NaN values.

# %% [raw]
# This shows that there is no missing values in the dataset

# %%
# Let's print 50 random rows from the dataset
suicide_rates.sample(n=25)
# Out:
#                                Region                             Country  \
# 1047        CENTRAL AND SOUTH AMERICA                               CHILE
# 2875                             ASIA                            MALDIVES
# 5023                           EUROPE                             UKRAINE
# 1369                           EUROPE                             GERMANY
# 911         CENTRAL AND SOUTH AMERICA                               CHILE
# 4494                           EUROPE                              SERBIA
# 4900                             ASIA                        TURKMENISTAN
# 3814                             ASIA                            MALAYSIA
# 3312                          OCEANIA                         NEW ZEALAND
# 5305        CENTRAL AND SOUTH AMERICA  VENEZUELA (BOLIVARIAN REPUBLIC OF)
# 2622                           EUROPE                             CROATIA
# 396   NORTH AMERICA AND THE CARIBBEAN                             BAHAMAS
# ...

# %% [raw]
# Changes made to the dataset:
# Step # 1: Replacing headers
# Step # 2: Dropping RegionCode and CountryCode
# Step # 3: Removing DeathRatePer100K, GDPPerCapita, GNIPerCapita
# Step # 4: Drop Inflation rate and EmploymentPopulationRatio
# Step # 5: Convert Region and Country to upper case
# Step # 6: Looking for duplicates
# Step # 7: Checking for missing values

# %% [raw]
# For this project, we were able to verify the source of the dataset. Eventhough we downloaded the dataset from Kaggle, we were able to verify that the data was imported from the Suicide prevention database from the World Health Organization, which is a reliable source.
# Because we are working with data related to suicide, we are making sure we do not leave any personal identifier in the dataset to ensure that the analysis is done anonymously. We are also making sure we are not intruducing any mistakes or biases in the dataset.
# Given the sensitive nature of the suicide data, we are making sure we are transperent and documenting all the steps we are taking. Any error could impact the accuracy and fairness of the result.

# %%
suicide_rates.to_csv('suicide_rates.csv')
